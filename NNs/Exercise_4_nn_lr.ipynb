# %% [markdown]
# <a href="https://colab.research.google.com/github/tallerzalan/Applied-Machine-Learning/blob/main/NNs/Exercise_4_nn_lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise - learning rate and batch size
#
# 1. Consider last exercise (i.e. the MNIST data). Suppose you are restricted to **training for only 2 epochs** but still want a good model. You recognize that finding the right learning rate is going to be very important. For this reason, you split your training data into a train and a validation set and use the validation set to find the optimal learning rate. Train a model with you optimized learning rate and evaluate it on your test data.
# 1. Recognizing that the batch size is also important for training speed, you decide to extend your above analysis to also find the optimal batch size. Once again, train a model with you optimized learning rate *and* batch size and evaluate it on your test data.
# 1. You have heard that momentum is important. You know that many optimizers already incorporate momentum by default, but you are now forced by your evil teacher to use SGD and otherwise repeat (1) and (2). You decide to extend your above analysis to also find the optimal momentum for SGD (see https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD for how to set it). Once again, train a model with you optimized learning rate, batch size, *and* momentum and evaluate it on your test data.
#
# **See slides for more details!**

# %% [markdown]
# # Exercise 1
#
# Consider last exercise (i.e. the MNIST data). Suppose you are restricted to **training for only 2 epochs** but still want a good model. You recognize that finding the right learning rate is going to be very important. For this reason, you split your training data into a train and a validation set and use the validation set to find the optimal learning rate. Train a model with you optimized learning rate and evaluate it on your test data.

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Activation, Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.optimizers import SGD, Adam
from keras import Input
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

random_seed = 42
from tensorflow.random import set_seed
set_seed(random_seed)

from numpy.random import seed
seed(random_seed)

# %%
test_size = 0.2

# Parameters
num_classes = 10
input_shape = (28, 28, 1)
epochs = 2

# %%
# Load the data and split it between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Scale images to the [0, 1] range
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# Make sure images have shape (28, 28, 1)
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)

# convert class vectors to binary class matrices
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# Split train data to also get val data
X_train, X_val, y_train, y_val = train_test_split(X_train,
                                                  y_train,
                                                  test_size = test_size,
                                                  random_state = random_seed
                                                  )

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (48000, 28, 28, 1) (48000, 10) (12000, 28, 28, 1) (12000, 10) (10000, 28, 28, 1) (10000, 10)

# %% [markdown]
# Here is (parts of) a model to get you started.
#
# It is very helpful to wrap it inside a function since you want to call it multiple times in a loop.
#
# Take note of the "Flatten" layer. This is important to reshape your data from (28, 28) to (784,).
#
# Alternatively, you could reshape your data (the x's). This can be done using:
#
# $\texttt{x = x.reshape(n, 784)}$
#
# where $n$ is the number of samples (60k for training, 10k for test).
#
# Then you don't need the Flatten layer, but remember to still specify an input shape of your first layer (i.e. 784 if you have done this reshaping).
#
# **Note**: Do feel free to experiment with the number of layers, nodes per layer, and optimizer.

# %%
def build_model(learning_rate):
  model = Sequential([
      Flatten(input_shape = input_shape),
      Dense(128, activation = 'relu'),
      Dense(64, activation = 'relu'),
      Dense(32, activation = 'relu'),
      Dense(num_classes)
      ])
  
  optimizer = Adam(learning_rate = learning_rate)
  
  model.compile(
      loss = 'categorical_crossentropy',
      optimizer = optimizer,
      metrics = ['accuracy']
      )
  
  return model

# %% [markdown]
# Let us look at single run.

# %%
model = build_model(0.001) # insert desired learning rate

model.fit(X_train,
          y_train,
          validation_data = (X_val, y_val),
          epochs = epochs
          )

model.evaluate(X_test, y_test)
# Out:
# Epoch 1/2
# 1500/1500 [==============================] - 7s 4ms/step - loss: 10.1502 - accuracy: 0.2035 - val_loss: 10.3895 - val_accuracy: 0.2338
# Epoch 2/2
# 1500/1500 [==============================] - 6s 4ms/step - loss: 10.3408 - accuracy: 0.2351 - val_loss: 10.3895 - val_accuracy: 0.2338
# 313/313 [==============================] - 1s 3ms/step - loss: 10.3897 - accuracy: 0.2307
# [10.389719009399414, 0.23070000112056732]

# %% [markdown]
# Now for the optimization.

# %%
learning_rates = [rate for rate in np.arange(0.0001, 1, 0.1)]

results = []

for learning_rate in learning_rates:
    model = build_model(learning_rate)
    model.fit(X_train,
              y_train,
              validation_data = (X_val, y_val),
              epochs = epochs,
              verbose = 0)
    
    loss, acc = model.evaluate(X_test, y_test)
    results.append((acc, learning_rate))
    
results = pd.DataFrame(results, columns = ['Accuracy', 'Learning rate'])
results
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 7.0609 - accuracy: 0.1364
# 313/313 [==============================] - 1s 3ms/step - loss: 6.4746 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 8.1106 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 8.0768 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 7.8560 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 8.2331 - accuracy: 0.0851
# 313/313 [==============================] - 1s 3ms/step - loss: 11.2649 - accuracy: 0.1059
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3310 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 7.9768 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 6.5713 - accuracy: 0.1010
#    Accuracy  Learning rate
# 0    0.1364         0.0001
# 1    0.0982         0.1001
# 2    0.1028         0.2001
# 3    0.0958         0.3001
# 4    0.0958         0.4001
# 5    0.0851         0.5001
# 6    0.1059         0.6001
# 7    0.0974         0.7001
# 8    0.1032         0.8001
# 9    0.1010         0.9001

# %%
results[results['Accuracy'] == results['Accuracy'].max()]
# Out:
#    Accuracy  Learning rate
# 0    0.1364         0.0001

# %%
model = build_model(0.0001) # insert desired learning rate

model.fit(np.concatenate([X_train, X_val]),
          np.concatenate([y_train, y_val]),
          epochs = epochs
          )

model.evaluate(X_test, y_test)
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 7.2458 - accuracy: 0.1196
# Epoch 2/2
# 1875/1875 [==============================] - 6s 3ms/step - loss: 8.0450 - accuracy: 0.1504
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2701 - accuracy: 0.1689
# [8.270132064819336, 0.1688999980688095]

# %% [markdown]
# # Exercise 2
#
# Recognizing that the batch size is also important for training speed, you decide to extend your above analysis to also find the optimal batch size. Once again, train a model with you optimized learning rate *and* batch size and evaluate it on your test data.

# %%
learning_rates = [rate for rate in np.arange(0.0001, 1, 0.1)]
batch_sizes = [size for size in range(16, 65, 16)] # # must be positive ints. Default is 32

results = []

for learning_rate in learning_rates:
    for batch_size in batch_sizes:
        model = build_model(learning_rate)
        model.fit(X_train,
                  y_train,
                  validation_data = (X_val, y_val),
                  epochs = epochs,
                  batch_size = batch_size,
                  verbose = 0)
        loss, acc = model.evaluate(X_test, y_test)
        results.append((acc, learning_rate, batch_size))
    
results = pd.DataFrame(results, columns = ['Accuracy', 'Learning rate', 'Batch size'])
results
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 7.5000 - accuracy: 0.0884
# 313/313 [==============================] - 1s 3ms/step - loss: 8.7772 - accuracy: 0.1265
# 313/313 [==============================] - 1s 3ms/step - loss: 7.5072 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 8.2415 - accuracy: 0.1042
# 313/313 [==============================] - 1s 3ms/step - loss: 6.2748 - accuracy: 0.0980
# 313/313 [==============================] - 1s 4ms/step - loss: 9.8739 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 6.1926 - accuracy: 0.0958
# 313/313 [==============================] - 1s 2ms/step - loss: 11.3375 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 4.6356 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 8.0768 - accuracy: 0.0612
# 313/313 [==============================] - 1s 3ms/step - loss: 9.8901 - accuracy: 0.1032
# 313/313 [==============================] - 1s 2ms/step - loss: 8.0607 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6708 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 4.8532 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6451 - accuracy: 0.1009
# 313/313 [==============================] - 1s 2ms/step - loss: 8.1380 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 8.1203 - accuracy: 0.1715
# 313/313 [==============================] - 1s 3ms/step - loss: 5.1352 - accuracy: 0.1339
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5081 - accuracy: 0.0980
# 313/313 [==============================] - 1s 2ms/step - loss: 8.3621 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5129 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3032 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 9.1357 - accuracy: 0.1028
# 313/313 [==============================] - 1s 2ms/step - loss: 8.1300 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 6.5230 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 6.6068 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 8.0719 - accuracy: 0.0982
# 313/313 [==============================] - 1s 2ms/step - loss: 6.4650 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3027 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 8.2654 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 6.4908 - accuracy: 0.1028
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3231 - accuracy: 0.1154
# 313/313 [==============================] - 1s 3ms/step - loss: 11.1876 - accuracy: 0.1422
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5951 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 11.9548 - accuracy: 0.1766
# 313/313 [==============================] - 1s 2ms/step - loss: 11.3020 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 7.8431 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 6.4650 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 6.4940 - accuracy: 0.1028
# 313/313 [==============================] - 1s 2ms/step - loss: 11.3197 - accuracy: 0.1010
#     Accuracy  Learning rate  Batch size
# 0     0.0884         0.0001          16
# 1     0.1265         0.0001          32
# 2     0.0982         0.0001          48
# 3     0.1042         0.0001          64
# 4     0.0980         0.1001          16
# 5     0.1028         0.1001          32
# 6     0.0958         0.1001          48
# 7     0.0982         0.1001          64
# 8     0.1028         0.2001          16
# 9     0.0612         0.2001          32
# 10    0.1032         0.2001          48
# 11    0.1032         0.2001          64
# 12    0.1010         0.3001          16
# 13    0.0974         0.3001          32
# 14    0.1009         0.3001          48
# 15    0.1135         0.3001          64
# 16    0.1715         0.4001          16
# 17    0.1339         0.4001          32
# 18    0.0980         0.4001          48
# 19    0.1009         0.4001          64
# 20    0.0958         0.5001          16
# 21    0.1010         0.5001          32
# 22    0.1028         0.5001          48
# 23    0.0892         0.5001          64
# 24    0.0958         0.6001          16
# 25    0.0892         0.6001          32
# 26    0.0982         0.6001          48
# 27    0.1135         0.6001          64
# 28    0.0974         0.7001          16
# 29    0.0958         0.7001          32
# 30    0.1028         0.7001          48
# 31    0.1154         0.7001          64
# 32    0.1422         0.8001          16
# 33    0.1028         0.8001          32
# 34    0.1766         0.8001          48
# 35    0.0974         0.8001          64
# 36    0.1028         0.9001          16
# 37    0.0980         0.9001          32
# 38    0.1028         0.9001          48
# 39    0.1010         0.9001          64

# %%
results[results['Accuracy'] == results['Accuracy'].max()]
# Out:
#     Accuracy  Learning rate  Batch size
# 34    0.1766         0.8001          48

# %%
model = build_model(0.8001) # insert desired learning rate

model.fit(np.concatenate([X_train, X_val]),
          np.concatenate([y_train, y_val]),
          batch_size = 48, 
          epochs = epochs
          )

model.evaluate(X_test, y_test)
# Out:
# Epoch 1/2
# 1250/1250 [==============================] - 5s 4ms/step - loss: 8.8578 - accuracy: 0.0993
# Epoch 2/2
# 1250/1250 [==============================] - 5s 4ms/step - loss: 9.4430 - accuracy: 0.0992
# 313/313 [==============================] - 1s 2ms/step - loss: 9.5081 - accuracy: 0.1009
# [9.508055686950684, 0.10090000182390213]

# %% [markdown]
# # Exericse 3
#
# You have heard that momentum is important. You know that many optimizers already incorporate momentum by default, but you are now forced by your evil teacher to use SGD and otherwise repeat (1) and (2). You decide to extend your above analysis to also find the optimal momentum for SGD (see https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD for how to set it). Once again, train a model with you optimized learning rate, batch size, *and* momentum and evaluate it on your test data.

# %%
def build_model_with_momentum(learning_rate, momentum):
    model = Sequential([
        Flatten(input_shape = input_shape),
        Dense(128, activation = 'relu'),
        Dense(64, activation = 'relu'),
        Dense(32, activation = 'relu'),
        Dense(num_classes)
        ])
    
    optimizer = SGD(learning_rate = learning_rate,
                    momentum = momentum
                    )
    
    model.compile(
        loss = 'categorical_crossentropy',
        optimizer = optimizer,
        metrics = ['accuracy']
        )
    
    return model

# %%
learning_rates = [rate for rate in np.arange(0.0001, 1, 0.1)]
batch_sizes = [size for size in range(16, 65, 16)] # # must be positive ints. Default is 32
momentums = [moment for moment in np.arange(0, 1, 0.2)] # must be in [0, 1). Default (for SGD) is 0.0

results = []

for learning_rate in learning_rates:
    for batch_size in batch_sizes:
        for momentum in momentums:
            model = build_model_with_momentum(learning_rate, momentum)
            model.fit(X_train,
                      y_train,
                      validation_data = (X_val, y_val),
                      epochs = epochs,
                      batch_size = batch_size,
                      verbose = 0)
            loss, acc = model.evaluate(X_test, y_test)
            results.append((acc, learning_rate, batch_size, momentum))
    
results = pd.DataFrame(results, columns=['Accuracy', 'Learning rate', 'Batch size', 'Momentum'])
results
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 10.4768 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 8.6401 - accuracy: 0.1347
# 313/313 [==============================] - 1s 3ms/step - loss: 8.4193 - accuracy: 0.1010
# 313/313 [==============================] - 1s 4ms/step - loss: 10.7131 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5612 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5557 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 9.0413 - accuracy: 0.1154
# 313/313 [==============================] - 1s 3ms/step - loss: 7.8865 - accuracy: 0.0865
# 313/313 [==============================] - 1s 3ms/step - loss: 5.4322 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 7.7443 - accuracy: 0.0809
# 313/313 [==============================] - 1s 3ms/step - loss: 6.2432 - accuracy: 0.1920
# 313/313 [==============================] - 1s 3ms/step - loss: 6.0820 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 8.5966 - accuracy: 0.1101
# 313/313 [==============================] - 1s 3ms/step - loss: 8.2537 - accuracy: 0.1026
# 313/313 [==============================] - 1s 3ms/step - loss: 7.3011 - accuracy: 0.0978
# 313/313 [==============================] - 1s 2ms/step - loss: 3.6602 - accuracy: 0.1010
# 313/313 [==============================] - 1s 2ms/step - loss: 9.0509 - accuracy: 0.1010
# 313/313 [==============================] - 1s 2ms/step - loss: 7.6293 - accuracy: 0.1141
# 313/313 [==============================] - 1s 2ms/step - loss: 9.5709 - accuracy: 0.0892
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5771 - accuracy: 0.1036
# 313/313 [==============================] - 1s 3ms/step - loss: 9.9126 - accuracy: 0.1083
# 313/313 [==============================] - 1s 3ms/step - loss: 9.7692 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 9.4275 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6531 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 6.7696 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 8.0864 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 11.2392 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 12.8848 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 11.2472 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 11.0796 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 9.3985 - accuracy: 0.0608
# 313/313 [==============================] - 1s 3ms/step - loss: 3.2091 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5967 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6032 - accuracy: 0.1003
# 313/313 [==============================] - 1s 3ms/step - loss: 4.8161 - accuracy: 0.1009
# 313/313 [==============================] - 1s 2ms/step - loss: 7.8124 - accuracy: 0.1637
# 313/313 [==============================] - 1s 2ms/step - loss: 9.5451 - accuracy: 0.1028
# 313/313 [==============================] - 1s 2ms/step - loss: 9.5000 - accuracy: 0.0958
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2637 - accuracy: 0.0980
# 313/313 [==============================] - 1s 2ms/step - loss: 12.9122 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 8.1493 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 9.0197 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3278 - accuracy: 0.1110
# 313/313 [==============================] - 1s 3ms/step - loss: 9.7950 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5081 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 8.5909 - accuracy: 0.1575
# 313/313 [==============================] - 1s 3ms/step - loss: 6.3505 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 11.5551 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6451 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 8.3588 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 9.4790 - accuracy: 0.0956
# 313/313 [==============================] - 1s 3ms/step - loss: 14.4611 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 11.1618 - accuracy: 0.1688
# 313/313 [==============================] - 1s 3ms/step - loss: 8.7151 - accuracy: 0.0983
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3407 - accuracy: 0.1032
# 313/313 [==============================] - 1s 2ms/step - loss: 9.7950 - accuracy: 0.1128
# 313/313 [==============================] - 1s 2ms/step - loss: 8.1574 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 9.7804 - accuracy: 0.1032
# 313/313 [==============================] - 1s 2ms/step - loss: 9.6999 - accuracy: 0.0980
# 313/313 [==============================] - 1s 2ms/step - loss: 9.8207 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5919 - accuracy: 0.1146
# 313/313 [==============================] - 1s 3ms/step - loss: 14.5353 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 8.1574 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 12.6608 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 7.9204 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 14.2887 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 6.4295 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 7.8076 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 7.9607 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5967 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 6.6568 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 12.8848 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 11.4825 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 11.0522 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 13.0170 - accuracy: 0.1135
# 313/313 [==============================] - 1s 2ms/step - loss: 11.1183 - accuracy: 0.0892
# 313/313 [==============================] - 1s 2ms/step - loss: 13.0524 - accuracy: 0.0984
# 313/313 [==============================] - 1s 2ms/step - loss: 12.7091 - accuracy: 0.1135
# 313/313 [==============================] - 1s 2ms/step - loss: 12.8751 - accuracy: 0.0892
# 313/313 [==============================] - 1s 2ms/step - loss: 7.8527 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 9.7047 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 6.6648 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 8.3298 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 9.8933 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6563 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3762 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 14.5740 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6451 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6531 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 11.4406 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 9.3694 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 10.9974 - accuracy: 0.0979
# 313/313 [==============================] - 1s 3ms/step - loss: 8.1026 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 6.5423 - accuracy: 0.1168
# 313/313 [==============================] - 1s 3ms/step - loss: 6.6165 - accuracy: 0.1032
# 313/313 [==============================] - 1s 2ms/step - loss: 9.6177 - accuracy: 0.0958
# 313/313 [==============================] - 1s 2ms/step - loss: 7.9317 - accuracy: 0.1010
# 313/313 [==============================] - 1s 2ms/step - loss: 11.1618 - accuracy: 0.1032
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3102 - accuracy: 0.1028
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3409 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 11.1038 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 11.1618 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 6.6390 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 8.0671 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 11.5567 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3020 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 6.5165 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 8.1541 - accuracy: 0.1716
# 313/313 [==============================] - 1s 3ms/step - loss: 6.6100 - accuracy: 0.1000
# 313/313 [==============================] - 1s 3ms/step - loss: 6.5842 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 9.9868 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 6.3328 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 9.8643 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 7.7625 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 13.1008 - accuracy: 0.0980
# 313/313 [==============================] - 1s 2ms/step - loss: 12.9106 - accuracy: 0.0952
# 313/313 [==============================] - 1s 2ms/step - loss: 6.5037 - accuracy: 0.0980
# 313/313 [==============================] - 1s 2ms/step - loss: 9.8546 - accuracy: 0.0892
# 313/313 [==============================] - 1s 2ms/step - loss: 4.9483 - accuracy: 0.1010
# 313/313 [==============================] - 1s 2ms/step - loss: 9.8643 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 9.3236 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 8.0768 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5661 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 9.8465 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 12.6318 - accuracy: 0.0974
# 313/313 [==============================] - 1s 4ms/step - loss: 9.6209 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 12.9170 - accuracy: 0.0997
# 313/313 [==============================] - 1s 3ms/step - loss: 6.1910 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 12.8639 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5371 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 9.4694 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 11.0828 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3278 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 12.9654 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 6.5617 - accuracy: 0.0974
# 313/313 [==============================] - 1s 2ms/step - loss: 9.9304 - accuracy: 0.1114
# 313/313 [==============================] - 1s 2ms/step - loss: 11.5099 - accuracy: 0.0982
# 313/313 [==============================] - 1s 2ms/step - loss: 9.5048 - accuracy: 0.0958
# 313/313 [==============================] - 1s 2ms/step - loss: 8.1541 - accuracy: 0.1032
# 313/313 [==============================] - 1s 2ms/step - loss: 11.2633 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 8.3266 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 12.8284 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 8.2621 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 4.5614 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 11.5309 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 12.9106 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 9.7015 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 9.7772 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5097 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 7.8447 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 11.4680 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 9.9255 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 8.1284 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 7.9607 - accuracy: 0.0955
# 313/313 [==============================] - 1s 3ms/step - loss: 10.9684 - accuracy: 0.1009
# 313/313 [==============================] - 1s 2ms/step - loss: 9.6048 - accuracy: 0.0958
# 313/313 [==============================] - 1s 2ms/step - loss: 9.7144 - accuracy: 0.1135
# 313/313 [==============================] - 1s 2ms/step - loss: 9.7579 - accuracy: 0.0980
# 313/313 [==============================] - 1s 2ms/step - loss: 6.6004 - accuracy: 0.0958
# 313/313 [==============================] - 1s 2ms/step - loss: 11.2230 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6112 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 7.9849 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 9.9868 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 7.8850 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 4.6646 - accuracy: 0.0892
# 313/313 [==============================] - 1s 3ms/step - loss: 9.5484 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3971 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 12.6318 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 12.9654 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3407 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 9.8111 - accuracy: 0.1547
# 313/313 [==============================] - 1s 3ms/step - loss: 12.6318 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 7.9607 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 6.4392 - accuracy: 0.1032
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6354 - accuracy: 0.1010
# 313/313 [==============================] - 1s 2ms/step - loss: 9.8175 - accuracy: 0.1066
# 313/313 [==============================] - 1s 2ms/step - loss: 11.3391 - accuracy: 0.1135
# 313/313 [==============================] - 1s 2ms/step - loss: 9.5000 - accuracy: 0.0958
# 313/313 [==============================] - 1s 2ms/step - loss: 9.6080 - accuracy: 0.1028
# 313/313 [==============================] - 1s 2ms/step - loss: 6.6133 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 11.3423 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 6.2506 - accuracy: 0.1135
# 313/313 [==============================] - 1s 3ms/step - loss: 4.8064 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 7.8817 - accuracy: 0.1028
# 313/313 [==============================] - 1s 3ms/step - loss: 6.5133 - accuracy: 0.1009
# 313/313 [==============================] - 1s 3ms/step - loss: 12.7059 - accuracy: 0.0958
# 313/313 [==============================] - 1s 3ms/step - loss: 6.7760 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 8.1026 - accuracy: 0.0974
# 313/313 [==============================] - 1s 3ms/step - loss: 12.8848 - accuracy: 0.0970
# 313/313 [==============================] - 1s 3ms/step - loss: 12.9944 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 12.9944 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 9.6144 - accuracy: 0.0982
# 313/313 [==============================] - 1s 3ms/step - loss: 12.9203 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 6.6068 - accuracy: 0.1010
# 313/313 [==============================] - 1s 3ms/step - loss: 9.8675 - accuracy: 0.1028
# 313/313 [==============================] - 1s 2ms/step - loss: 6.2894 - accuracy: 0.0892
# 313/313 [==============================] - 1s 2ms/step - loss: 13.1105 - accuracy: 0.0892
# 313/313 [==============================] - 1s 2ms/step - loss: 4.9918 - accuracy: 0.0980
# 313/313 [==============================] - 1s 3ms/step - loss: 4.6968 - accuracy: 0.0958
# 313/313 [==============================] - 1s 2ms/step - loss: 4.8499 - accuracy: 0.0892
#      Accuracy  Learning rate  Batch size  Momentum
# 0      0.0892         0.0001          16       0.0
# 1      0.1347         0.0001          16       0.2
# 2      0.1010         0.0001          16       0.4
# 3      0.0982         0.0001          16       0.6
# 4      0.0958         0.0001          16       0.8
# ..        ...            ...         ...       ...
# 195    0.0892         0.9001          64       0.0
# 196    0.0892         0.9001          64       0.2
# 197    0.0980         0.9001          64       0.4
# 198    0.0958         0.9001          64       0.6
# 199    0.0892         0.9001          64       0.8
#
# [200 rows x 4 columns]

# %%
results[results['Accuracy'] == results['Accuracy'].max()]
# Out:
#     Accuracy  Learning rate  Batch size  Momentum
# 10     0.192         0.0001          48       0.0

# %%
model = build_model_with_momentum(0.0001, 0) # insert desired learning rate

model.fit(np.concatenate([X_train, X_val]),
          np.concatenate([y_train, y_val]),
          batch_size = 48, 
          epochs = epochs
          )

model.evaluate(X_test, y_test)
# Out:
# Epoch 1/2
# 1250/1250 [==============================] - 5s 3ms/step - loss: 6.9034 - accuracy: 0.1182
# Epoch 2/2
# 1250/1250 [==============================] - 5s 4ms/step - loss: 5.1473 - accuracy: 0.0981
# 313/313 [==============================] - 1s 2ms/step - loss: 4.2437 - accuracy: 0.0974
# [4.243669033050537, 0.09740000218153]
